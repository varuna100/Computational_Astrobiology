# %% [markdown]
# <a href="https://colab.research.google.com/github/varuna100/Computational_Astrobiology/blob/main/PSG_Dataplots_Varuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Planet demo : https://psg.gsfc.nasa.gov/index.php
# '''  GJ 1214b
# Geometry: GJ 1214b measured via Observatory from 14.6427 pc for date (2020/04/08 01:32 UT)
# Change Object
# Atmosphere and surface: Surface pressure: 1.0 bar; Molecular weight: 2.36 g/mol; Gases: H2,He,H2O,CH4;
# Surface temperature: 888.1 K; Albedo: 0.164; Emissivity: 0.836;	Change Composition
# Instrument parameters: Measurement range 0.5-17 um with a resolution of 200 RP.
# Molecular signatures included; Continuum/background fluxes enabled;'''

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the file and labelling the columns for RADIANCE SPECTRUM data
df_rad = pd.read_csv('psg_rad.txt', comment='#', delim_whitespace=True) #, header=None)
df_rad.columns = ['Wave/freq', 'Total', 'Noise', 'Stellar', 'GJ-1214b', 'Transit']
# Out:
# /tmp/ipykernel_12235/1434675678.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_rad = pd.read_csv('psg_rad.txt', comment='#', delim_whitespace=True) #, header=None)

# %%
print (df_rad)  # To display the data and the column variables
# Out:
#      Wave/freq     Total     Noise  Stellar  GJ-1214b   Transit
# 0     0.502500  0.015445  0.000448      1.0  0.015445  0.015445
# 1     0.505012  0.015440  0.000438      1.0  0.015440  0.015440
# 2     0.507538  0.015432  0.000428      1.0  0.015432  0.015432
# 3     0.510075  0.015421  0.000419      1.0  0.015421  0.015421
# 4     0.512626  0.015410  0.000409      1.0  0.015410  0.015410
# ..         ...       ...       ...      ...       ...       ...
# 702  16.661397  0.014755  0.001170      1.0  0.014755  0.015976
# 703  16.744704  0.014155  0.001187      1.0  0.014155  0.015791
# 704  16.828428  0.014321  0.001204      1.0  0.014320  0.015868
# 705  16.912570  0.014676  0.001221      1.0  0.014676  0.015989
# 706  16.997133  0.014114  0.001239      1.0  0.014114  0.015778
#
# [707 rows x 6 columns]

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_rad['Wave/freq'], df_rad['Total'], label='Total Signal', color='black', linewidth=1.5)
#plt.plot(df_rad['Wave/freq'], df_rad['Noise'], label='Noise', alpha=0.7)
#plt.plot(df_rad['Wave/freq'], df_rad['Stellar'], label='Stellar', alpha=0.7) # This one is not necessary
plt.plot(df_rad['Wave/freq'], df_rad['GJ-1214b'], label='GJ-1214b', alpha=0.7)
plt.plot(df_rad['Wave/freq'], df_rad['Transit'], label='Transit', alpha=0.7)



plt.xlabel('Wavelength [$\mu$m]')
plt.xscale('log')
plt.ylabel('Radiance [W/sr/m$^2$/$\mu$m]')
plt.title('Simulated Planetary Spectrum for GJ-1214b - Radiance')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:12: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_12235/148084118.py:10: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Wavelength [$\mu$m]')
# /tmp/ipykernel_12235/148084118.py:12: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('Radiance [W/sr/m$^2$/$\mu$m]')

# %%
# Reading the file and labelling the columns for TRANSMITTANCE SPECTRUM data
df_trn = pd.read_csv('psg_trn.txt', comment='#', delim_whitespace=True) #, header=None)
df_trn.columns = ['Wave/freq', 'Total', 'H2', 'He', 'H2O', 'CH4', 'Rayleigh', 'CIA']
# Out:
# /tmp/ipykernel_12235/14084969.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_trn = pd.read_csv('psg_trn.txt', comment='#', delim_whitespace=True) #, header=None)

# %%
print(df_trn) #displaying the data in columns for transmittance
# Out:
#      Wave/freq     Total            H2            He       H2O       CH4  \
# 0     0.502500  0.001072  4.207400e-09  3.950660e-09  0.000057  0.000001
# 1     0.505012  0.001066  3.950660e-09  3.950660e-09  0.000066  0.000002
# 2     0.507538  0.001059  3.952550e-09  3.950660e-09  0.000063  0.000004
# 3     0.510075  0.001048  4.024510e-09  3.950660e-09  0.000049  0.000006
# 4     0.512626  0.001037  4.061340e-09  3.950660e-09  0.000036  0.000003
# ..         ...       ...           ...           ...       ...       ...
# 702  16.661397  0.001602  2.006740e-08  3.950660e-09  0.001568  0.000329
# 703  16.744704  0.001417  4.337990e-08  3.950660e-09  0.001323  0.000252
# 704  16.828428  0.001494  5.031620e-06  3.950660e-09  0.001432  0.000281
# 705  16.912570  0.001616  2.059890e-05  3.950660e-09  0.001579  0.000352
# 706  16.997133  0.001404  4.818080e-06  3.950660e-09  0.001308  0.000275
#
#          Rayleigh           CIA
# 0    1.062490e-03  4.995430e-09
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(df_trn['Wave/freq'], df_trn['Total'], label='Total Signal', color='black', linewidth=1.5)
plt.plot(df_trn['Wave/freq'], df_trn['H2'], label='H2', alpha=0.7)
plt.plot(df_trn['Wave/freq'], df_trn['He'], label='He', alpha=0.7)
plt.plot(df_trn['Wave/freq'], df_trn['H2O'], label='H2O', alpha=0.7)
plt.plot(df_trn['Wave/freq'], df_trn['CH4'], label='CH4', alpha=0.7)
plt.plot(df_trn['Wave/freq'], df_trn['Rayleigh'], label='Rayleigh', alpha=0.7)
plt.plot(df_trn['Wave/freq'], df_trn['CIA'], label='CIA', alpha=0.7)


plt.xlabel('Wavelength [$\mu$m]')
plt.xscale('log')
plt.ylabel('Transmittance')
plt.title('Simulated Planetary Spectrum for GJ-1214b - Tansmittance')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# <>:11: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_12235/1973905281.py:11: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Wavelength [$\mu$m]')
